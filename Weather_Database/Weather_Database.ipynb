# %%
# Import the dependicies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from datetime import datetime

# Import the API key
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90, 90, size = 2000)
lngs = np.random.uniform(-180, 180, size = 2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# Create a list for holding the cities
cities = []
# Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 781

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 802,
#    'main': 'Clouds',
#    'description': 'scattered clouds',
#    'icon': '03n'}],
#  'base': 'stations',
#  'main': {'temp': 46.42,
#   'feels_like': 44.19,
#   'temp_min': 42.33,
#   'temp_max': 51.42,
#   'pressure': 1021,
#   'humidity': 72},
#  'visibility': 10000,
#  'wind': {'speed': 4.74, 'deg': 236, 'gust': 9.8},
#  'clouds': {'all': 44},
#  'dt': 1635120000,
#  'sys': {'type': 2,
#   'id': 2010120,
#   'country': 'US',
#   'sunrise': 1635073671,
#   'sunset': 1635112120},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Create an empty list to hold the weather data
city_data = []
# Print the beginning of the logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count
    record_count += 1
    
# Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_desc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Weather Description": city_weather_desc,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kapaa
# Processing Record 2 of Set 1 | qaanaaq
# Processing Record 3 of Set 1 | sheridan
# Processing Record 4 of Set 1 | atuona
# Processing Record 5 of Set 1 | vaini
# Processing Record 6 of Set 1 | dikson
# Processing Record 7 of Set 1 | ancud
# Processing Record 8 of Set 1 | rio grande
# Processing Record 9 of Set 1 | rocha
# Processing Record 10 of Set 1 | hualmay
# Processing Record 11 of Set 1 | khatanga
# Processing Record 12 of Set 1 | colon
# Processing Record 13 of Set 1 | mataura
# Processing Record 14 of Set 1 | santa cruz
# Processing Record 15 of Set 1 | sao felix do xingu
# Processing Record 16 of Set 1 | hermanus
# Processing Record 17 of Set 1 | hobart
# Processing Record 18 of Set 1 | provideniya
# Processing Record 19 of Set 1 | forssa
# Processing Record 20 of Set 1 | lebu
# Processing Record 21 of Set 1 | rikitea
# Processing Record 22 of Set 1 | west chicago
# Processing Record 23 of Set 1 | marfino
# Processing Record 24 of Set 1 | morondava
# Processing Record 25 of Set 1 | jamestown
# Processing Record 26 of Set 1 | aqtobe
# Processing Record 27 of Set 1 | sept-iles
# Processing Record 28 of Set 1 | kavieng
# Processing Record 29 of Set 1 | alofi
# Processing Record 30 of Set 1 | mar del plata
# Processing Record 31 of Set 1 | porto franco
# Processing Record 32 of Set 1 | chuy
# Processing Record 33 of Set 1 | terrace
# Processing Record 34 of Set 1 | khorixas
# Processing Record 35 of Set 1 | butaritari
# Processing Record 36 of Set 1 | bambous virieux
# Processing Record 37 of Set 1 | geraldton
# Processing Record 38 of Set 1 | ushuaia
# Processing Record 39 of Set 1 | ribeira grande
# Processing Record 40 of Set 1 | coahuayana
# Processing Record 41 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 42 of Set 1 | touros
# Processing Record 43 of Set 1 | pervomayskiy
# Processing Record 44 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 45 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 46 of Set 1 | havoysund
# Processing Record 47 of Set 1 | shahjahanpur
# Processing Record 48 of Set 1 | afmadu
# City not found. Skipping...
# Processing Record 49 of Set 1 | adlay
# Processing Record 50 of Set 1 | esperance
# Processing Record 1 of Set 2 | bluff
# Processing Record 2 of Set 2 | guilin
# Processing Record 3 of Set 2 | albany
# Processing Record 4 of Set 2 | haibowan
# City not found. Skipping...
# Processing Record 5 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 6 of Set 2 | inirida
# Processing Record 7 of Set 2 | oktyabrskoye
# Processing Record 8 of Set 2 | byron bay
# Processing Record 9 of Set 2 | punta arenas
# Processing Record 10 of Set 2 | hithadhoo
# Processing Record 11 of Set 2 | dakar
# Processing Record 12 of Set 2 | hilo
# Processing Record 13 of Set 2 | cabo san lucas
# Processing Record 14 of Set 2 | roma
# Processing Record 15 of Set 2 | kaardi
# City not found. Skipping...
# Processing Record 16 of Set 2 | thompson
# Processing Record 17 of Set 2 | coos bay
# Processing Record 18 of Set 2 | flinders
# Processing Record 19 of Set 2 | dotnuva
# Processing Record 20 of Set 2 | hovd
# Processing Record 21 of Set 2 | vakhrushev
# Processing Record 22 of Set 2 | bredasdorp
# Processing Record 23 of Set 2 | port alfred
# Processing Record 24 of Set 2 | san cristobal
# Processing Record 25 of Set 2 | bexhill
# Processing Record 26 of Set 2 | cape town
# Processing Record 27 of Set 2 | victoria point
# Processing Record 28 of Set 2 | davila
# Processing Record 29 of Set 2 | tuktoyaktuk
# Processing Record 30 of Set 2 | shache
# Processing Record 31 of Set 2 | sao joao da barra
# Processing Record 32 of Set 2 | meulaboh
# Processing Record 33 of Set 2 | kaitangata
# Processing Record 34 of Set 2 | la ronge
# Processing Record 35 of Set 2 | hambantota
# Processing Record 36 of Set 2 | saint george
# Processing Record 37 of Set 2 | walvis bay
# Processing Record 38 of Set 2 | champerico
# Processing Record 39 of Set 2 | kisaran
# Processing Record 40 of Set 2 | yellowknife
# Processing Record 41 of Set 2 | fairbanks
# Processing Record 42 of Set 2 | hamilton
# Processing Record 43 of Set 2 | tortoli
# Processing Record 44 of Set 2 | tokur
# Processing Record 45 of Set 2 | sao filipe
# Processing Record 46 of Set 2 | grants
# Processing Record 47 of Set 2 | fare
# Processing Record 48 of Set 2 | tombouctou
# Processing Record 49 of Set 2 | mandurah
# Processing Record 50 of Set 2 | castro
# Processing Record 1 of Set 3 | providencia
# Processing Record 2 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 3 of Set 3 | brae
# Processing Record 4 of Set 3 | loandjili
# Processing Record 5 of Set 3 | kulhudhuffushi
# Processing Record 6 of Set 3 | togur
# Processing Record 7 of Set 3 | nikolskoye
# Processing Record 8 of Set 3 | bethel
# Processing Record 9 of Set 3 | new norfolk
# Processing Record 10 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 3 | busselton
# Processing Record 12 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 13 of Set 3 | puerto ayora
# Processing Record 14 of Set 3 | port keats
# Processing Record 15 of Set 3 | solnechnyy
# Processing Record 16 of Set 3 | korla
# Processing Record 17 of Set 3 | tabou
# Processing Record 18 of Set 3 | hinton
# Processing Record 19 of Set 3 | gat
# Processing Record 20 of Set 3 | bargal
# City not found. Skipping...
# Processing Record 21 of Set 3 | san quintin
# Processing Record 22 of Set 3 | zhigansk
# Processing Record 23 of Set 3 | balsas
# Processing Record 24 of Set 3 | norman wells
# Processing Record 25 of Set 3 | roald
# Processing Record 26 of Set 3 | kaeo
# Processing Record 27 of Set 3 | sooke
# Processing Record 28 of Set 3 | richards bay
# Processing Record 29 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 30 of Set 3 | caborca
# Processing Record 31 of Set 3 | malwan
# City not found. Skipping...
# Processing Record 32 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 33 of Set 3 | nome
# Processing Record 34 of Set 3 | cayenne
# Processing Record 35 of Set 3 | cherskiy
# Processing Record 36 of Set 3 | svetlyy
# Processing Record 37 of Set 3 | kirakira
# Processing Record 38 of Set 3 | kodiak
# Processing Record 39 of Set 3 | bairiki
# Processing Record 40 of Set 3 | todos santos
# Processing Record 41 of Set 3 | yatou
# Processing Record 42 of Set 3 | cidreira
# Processing Record 43 of Set 3 | molochnoye
# Processing Record 44 of Set 3 | luderitz
# Processing Record 45 of Set 3 | kars
# Processing Record 46 of Set 3 | georgetown
# Processing Record 47 of Set 3 | cocobeach
# Processing Record 48 of Set 3 | elmira
# Processing Record 49 of Set 3 | novopokrovka
# Processing Record 50 of Set 3 | carnarvon
# Processing Record 1 of Set 4 | east london
# Processing Record 2 of Set 4 | bardsir
# Processing Record 3 of Set 4 | saint-louis
# Processing Record 4 of Set 4 | zhaotong
# Processing Record 5 of Set 4 | eenhana
# Processing Record 6 of Set 4 | coquimbo
# Processing Record 7 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 8 of Set 4 | koumac
# Processing Record 9 of Set 4 | southbridge
# Processing Record 10 of Set 4 | rawson
# Processing Record 11 of Set 4 | guerrero negro
# Processing Record 12 of Set 4 | egvekinot
# Processing Record 13 of Set 4 | otradnoye
# Processing Record 14 of Set 4 | chernyshkovskiy
# Processing Record 15 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 16 of Set 4 | highland springs
# Processing Record 17 of Set 4 | avarua
# Processing Record 18 of Set 4 | matara
# Processing Record 19 of Set 4 | hami
# Processing Record 20 of Set 4 | altay
# Processing Record 21 of Set 4 | nantucket
# Processing Record 22 of Set 4 | carutapera
# Processing Record 23 of Set 4 | bur gabo
# City not found. Skipping...
# Processing Record 24 of Set 4 | novomykolayivka
# Processing Record 25 of Set 4 | hit
# Processing Record 26 of Set 4 | leningradskiy
# Processing Record 27 of Set 4 | saskylakh
# Processing Record 28 of Set 4 | yekaterinogradskaya
# Processing Record 29 of Set 4 | skjervoy
# Processing Record 30 of Set 4 | port moresby
# Processing Record 31 of Set 4 | litovko
# Processing Record 32 of Set 4 | isangel
# Processing Record 33 of Set 4 | fortuna
# Processing Record 34 of Set 4 | warrnambool
# Processing Record 35 of Set 4 | clyde river
# Processing Record 36 of Set 4 | bengkulu
# Processing Record 37 of Set 4 | falealupo
# City not found. Skipping...
# Processing Record 38 of Set 4 | airai
# Processing Record 39 of Set 4 | darnah
# Processing Record 40 of Set 4 | mae chan
# Processing Record 41 of Set 4 | muborak
# Processing Record 42 of Set 4 | severo-kurilsk
# Processing Record 43 of Set 4 | manokwari
# Processing Record 44 of Set 4 | tromso
# Processing Record 45 of Set 4 | khairabad
# Processing Record 46 of Set 4 | karauzyak
# City not found. Skipping...
# Processing Record 47 of Set 4 | bubaque
# Processing Record 48 of Set 4 | quiindy
# Processing Record 49 of Set 4 | nizhneshilovka
# City not found. Skipping...
# Processing Record 50 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 1 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 2 of Set 5 | suez
# Processing Record 3 of Set 5 | tuatapere
# Processing Record 4 of Set 5 | kenai
# Processing Record 5 of Set 5 | longyearbyen
# Processing Record 6 of Set 5 | malanje
# Processing Record 7 of Set 5 | aitape
# Processing Record 8 of Set 5 | kilindoni
# Processing Record 9 of Set 5 | janauba
# Processing Record 10 of Set 5 | peniche
# Processing Record 11 of Set 5 | viligili
# City not found. Skipping...
# Processing Record 12 of Set 5 | bathsheba
# Processing Record 13 of Set 5 | lixourion
# Processing Record 14 of Set 5 | bandarbeyla
# Processing Record 15 of Set 5 | caravelas
# Processing Record 16 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 17 of Set 5 | kadykchan
# City not found. Skipping...
# Processing Record 18 of Set 5 | vanimo
# Processing Record 19 of Set 5 | kavaratti
# Processing Record 20 of Set 5 | vestmannaeyjar
# Processing Record 21 of Set 5 | barrow
# Processing Record 22 of Set 5 | kruisfontein
# Processing Record 23 of Set 5 | olafsvik
# Processing Record 24 of Set 5 | imeni poliny osipenko
# Processing Record 25 of Set 5 | los llanos de aridane
# Processing Record 26 of Set 5 | dunedin
# Processing Record 27 of Set 5 | narsaq
# Processing Record 28 of Set 5 | kochi
# Processing Record 29 of Set 5 | seoul
# Processing Record 30 of Set 5 | ambunti
# Processing Record 31 of Set 5 | petrokamenskoye
# Processing Record 32 of Set 5 | afyonkarahisar
# Processing Record 33 of Set 5 | fernie
# Processing Record 34 of Set 5 | yunjinghong
# City not found. Skipping...
# Processing Record 35 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 36 of Set 5 | denpasar
# Processing Record 37 of Set 5 | minnedosa
# Processing Record 38 of Set 5 | pozo colorado
# Processing Record 39 of Set 5 | tiksi
# Processing Record 40 of Set 5 | kazalinsk
# City not found. Skipping...
# Processing Record 41 of Set 5 | torbay
# Processing Record 42 of Set 5 | lattes
# Processing Record 43 of Set 5 | sobolevo
# Processing Record 44 of Set 5 | dickinson
# Processing Record 45 of Set 5 | labuhan
# Processing Record 46 of Set 5 | sitka
# Processing Record 47 of Set 5 | biltine
# Processing Record 48 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 49 of Set 5 | souillac
# Processing Record 50 of Set 5 | orange cove
# Processing Record 1 of Set 6 | tungor
# Processing Record 2 of Set 6 | mahebourg
# Processing Record 3 of Set 6 | turtkul
# City not found. Skipping...
# Processing Record 4 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 5 of Set 6 | college
# Processing Record 6 of Set 6 | boden
# Processing Record 7 of Set 6 | shimoda
# Processing Record 8 of Set 6 | urdzhar
# City not found. Skipping...
# Processing Record 9 of Set 6 | pisco
# Processing Record 10 of Set 6 | port hedland
# Processing Record 11 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 12 of Set 6 | iztapa
# Processing Record 13 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 14 of Set 6 | victoria
# Processing Record 15 of Set 6 | tasiilaq
# Processing Record 16 of Set 6 | omagari
# Processing Record 17 of Set 6 | aswan
# Processing Record 18 of Set 6 | yarim
# Processing Record 19 of Set 6 | vanavara
# Processing Record 20 of Set 6 | deputatskiy
# Processing Record 21 of Set 6 | tayoltita
# Processing Record 22 of Set 6 | vestmanna
# Processing Record 23 of Set 6 | lagoa
# Processing Record 24 of Set 6 | acapulco
# Processing Record 25 of Set 6 | upernavik
# Processing Record 26 of Set 6 | beruwala
# Processing Record 27 of Set 6 | grand gaube
# Processing Record 28 of Set 6 | tevaitoa
# Processing Record 29 of Set 6 | ukiah
# Processing Record 30 of Set 6 | husavik
# Processing Record 31 of Set 6 | buala
# Processing Record 32 of Set 6 | new iberia
# Processing Record 33 of Set 6 | varhaug
# Processing Record 34 of Set 6 | salinopolis
# Processing Record 35 of Set 6 | abay
# Processing Record 36 of Set 6 | lasa
# Processing Record 37 of Set 6 | vallenar
# Processing Record 38 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 39 of Set 6 | tianpeng
# Processing Record 40 of Set 6 | chaohu
# Processing Record 41 of Set 6 | pashiya
# Processing Record 42 of Set 6 | san ramon
# Processing Record 43 of Set 6 | san-pedro
# Processing Record 44 of Set 6 | nouadhibou
# Processing Record 45 of Set 6 | bay roberts
# Processing Record 46 of Set 6 | waipawa
# Processing Record 47 of Set 6 | coihaique
# Processing Record 48 of Set 6 | belmonte
# Processing Record 49 of Set 6 | kolpashevo
# Processing Record 50 of Set 6 | kenner
# Processing Record 1 of Set 7 | shagamu
# Processing Record 2 of Set 7 | ballina
# Processing Record 3 of Set 7 | port macquarie
# Processing Record 4 of Set 7 | pevek
# Processing Record 5 of Set 7 | port shepstone
# Processing Record 6 of Set 7 | naze
# Processing Record 7 of Set 7 | arraial do cabo
# Processing Record 8 of Set 7 | itaituba
# Processing Record 9 of Set 7 | nesbyen
# Processing Record 10 of Set 7 | ossora
# Processing Record 11 of Set 7 | komsomolskiy
# Processing Record 12 of Set 7 | dingle
# Processing Record 13 of Set 7 | aguimes
# Processing Record 14 of Set 7 | port elizabeth
# Processing Record 15 of Set 7 | pulandian
# Processing Record 16 of Set 7 | general roca
# Processing Record 17 of Set 7 | merauke
# Processing Record 18 of Set 7 | chalus
# Processing Record 19 of Set 7 | progreso
# Processing Record 20 of Set 7 | whitianga
# Processing Record 21 of Set 7 | yauya
# Processing Record 22 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 23 of Set 7 | asau
# Processing Record 24 of Set 7 | bilma
# Processing Record 25 of Set 7 | san patricio
# Processing Record 26 of Set 7 | vostok
# Processing Record 27 of Set 7 | lakes entrance
# Processing Record 28 of Set 7 | surt
# Processing Record 29 of Set 7 | saint-pierre
# Processing Record 30 of Set 7 | nyagan
# Processing Record 31 of Set 7 | tambopata
# Processing Record 32 of Set 7 | mafinga
# Processing Record 33 of Set 7 | umm lajj
# Processing Record 34 of Set 7 | bayir
# Processing Record 35 of Set 7 | zhangye
# Processing Record 36 of Set 7 | tapaua
# City not found. Skipping...
# Processing Record 37 of Set 7 | ariquemes
# Processing Record 38 of Set 7 | rio gallegos
# Processing Record 39 of Set 7 | kroya
# Processing Record 40 of Set 7 | kalmunai
# Processing Record 41 of Set 7 | saint-philippe
# Processing Record 42 of Set 7 | nador
# Processing Record 43 of Set 7 | saldanha
# Processing Record 44 of Set 7 | anloga
# Processing Record 45 of Set 7 | ust-kut
# Processing Record 46 of Set 7 | jiangyou
# Processing Record 47 of Set 7 | ilulissat
# Processing Record 48 of Set 7 | riberalta
# Processing Record 49 of Set 7 | verkhnevilyuysk
# Processing Record 50 of Set 7 | tautira
# Processing Record 1 of Set 8 | gezing
# Processing Record 2 of Set 8 | canton
# Processing Record 3 of Set 8 | ternate
# Processing Record 4 of Set 8 | aykhal
# Processing Record 5 of Set 8 | chimore
# Processing Record 6 of Set 8 | castries
# Processing Record 7 of Set 8 | natal
# Processing Record 8 of Set 8 | nacunday
# City not found. Skipping...
# Processing Record 9 of Set 8 | freetown
# Processing Record 10 of Set 8 | rimbey
# Processing Record 11 of Set 8 | sisimiut
# Processing Record 12 of Set 8 | linxia
# Processing Record 13 of Set 8 | pokhara
# Processing Record 14 of Set 8 | ust-nera
# Processing Record 15 of Set 8 | rheinbach
# Processing Record 16 of Set 8 | qaqortoq
# Processing Record 17 of Set 8 | port lincoln
# Processing Record 18 of Set 8 | daxian
# City not found. Skipping...
# Processing Record 19 of Set 8 | sakakah
# Processing Record 20 of Set 8 | flin flon
# Processing Record 21 of Set 8 | manutuke
# Processing Record 22 of Set 8 | blonduos
# City not found. Skipping...
# Processing Record 23 of Set 8 | mrirt
# City not found. Skipping...
# Processing Record 24 of Set 8 | ahipara
# Processing Record 25 of Set 8 | ushtobe
# Processing Record 26 of Set 8 | kidal
# Processing Record 27 of Set 8 | lodja
# Processing Record 28 of Set 8 | sunrise manor
# Processing Record 29 of Set 8 | sinegorye
# Processing Record 30 of Set 8 | macuspana
# Processing Record 31 of Set 8 | taltal
# Processing Record 32 of Set 8 | havelock
# Processing Record 33 of Set 8 | atambua
# Processing Record 34 of Set 8 | la rioja
# Processing Record 35 of Set 8 | leshukonskoye
# Processing Record 36 of Set 8 | northam
# Processing Record 37 of Set 8 | kahului
# Processing Record 38 of Set 8 | conceicao da barra
# Processing Record 39 of Set 8 | yulara
# Processing Record 40 of Set 8 | santa isabel
# Processing Record 41 of Set 8 | khvoynaya
# Processing Record 42 of Set 8 | vesoul
# Processing Record 43 of Set 8 | preobrazheniye
# Processing Record 44 of Set 8 | rebrikha
# Processing Record 45 of Set 8 | belyy yar
# Processing Record 46 of Set 8 | akyab
# Processing Record 47 of Set 8 | nampula
# Processing Record 48 of Set 8 | prince rupert
# Processing Record 49 of Set 8 | kattivakkam
# Processing Record 50 of Set 8 | tiarei
# Processing Record 1 of Set 9 | talnakh
# Processing Record 2 of Set 9 | solovetskiy
# City not found. Skipping...
# Processing Record 3 of Set 9 | moron
# Processing Record 4 of Set 9 | antsirabe
# Processing Record 5 of Set 9 | necochea
# Processing Record 6 of Set 9 | fort saint james
# Processing Record 7 of Set 9 | hasaki
# Processing Record 8 of Set 9 | varzelandia
# Processing Record 9 of Set 9 | hibbing
# Processing Record 10 of Set 9 | halapitan
# Processing Record 11 of Set 9 | impfondo
# Processing Record 12 of Set 9 | solwezi
# Processing Record 13 of Set 9 | lakatoro
# Processing Record 14 of Set 9 | chokurdakh
# Processing Record 15 of Set 9 | vilhena
# Processing Record 16 of Set 9 | honningsvag
# Processing Record 17 of Set 9 | le port
# Processing Record 18 of Set 9 | lovington
# Processing Record 19 of Set 9 | north bend
# Processing Record 20 of Set 9 | crab hill
# City not found. Skipping...
# Processing Record 21 of Set 9 | faanui
# Processing Record 22 of Set 9 | mayo
# Processing Record 23 of Set 9 | muros
# Processing Record 24 of Set 9 | bonavista
# Processing Record 25 of Set 9 | cozumel
# Processing Record 26 of Set 9 | benjamin hill
# Processing Record 27 of Set 9 | saryshagan
# City not found. Skipping...
# Processing Record 28 of Set 9 | svetlogorsk
# Processing Record 29 of Set 9 | kumi
# Processing Record 30 of Set 9 | leticia
# Processing Record 31 of Set 9 | yaan
# Processing Record 32 of Set 9 | freeport
# Processing Record 33 of Set 9 | samandag
# Processing Record 34 of Set 9 | kutum
# Processing Record 35 of Set 9 | kernersville
# Processing Record 36 of Set 9 | cairns
# Processing Record 37 of Set 9 | yamada
# Processing Record 38 of Set 9 | lamu
# Processing Record 39 of Set 9 | chernyshevskiy
# Processing Record 40 of Set 9 | newport
# Processing Record 41 of Set 9 | portland
# Processing Record 42 of Set 9 | areosa
# Processing Record 43 of Set 9 | yar-sale
# Processing Record 44 of Set 9 | muhos
# Processing Record 45 of Set 9 | salalah
# Processing Record 46 of Set 9 | bintulu
# Processing Record 47 of Set 9 | el dorado
# Processing Record 48 of Set 9 | nagato
# Processing Record 49 of Set 9 | mutsamudu
# City not found. Skipping...
# Processing Record 50 of Set 9 | unity
# Processing Record 1 of Set 10 | constitucion
# Processing Record 2 of Set 10 | olenino
# Processing Record 3 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 4 of Set 10 | derzhavinsk
# Processing Record 5 of Set 10 | bhimunipatnam
# Processing Record 6 of Set 10 | roela
# Processing Record 7 of Set 10 | zyryanka
# Processing Record 8 of Set 10 | atlantis
# Processing Record 9 of Set 10 | lingao
# Processing Record 10 of Set 10 | quatre cocos
# Processing Record 11 of Set 10 | hudson bay
# Processing Record 12 of Set 10 | pulsano
# Processing Record 13 of Set 10 | itarema
# Processing Record 14 of Set 10 | yegros
# Processing Record 15 of Set 10 | westport
# Processing Record 16 of Set 10 | loiza
# Processing Record 17 of Set 10 | mahibadhoo
# Processing Record 18 of Set 10 | grojec
# Processing Record 19 of Set 10 | hue
# Processing Record 20 of Set 10 | aklavik
# Processing Record 21 of Set 10 | el alto
# Processing Record 22 of Set 10 | biak
# Processing Record 23 of Set 10 | anzio
# Processing Record 24 of Set 10 | vila franca do campo
# Processing Record 25 of Set 10 | vao
# Processing Record 26 of Set 10 | blytheville
# Processing Record 27 of Set 10 | jacqueville
# Processing Record 28 of Set 10 | wawa
# Processing Record 29 of Set 10 | chima
# Processing Record 30 of Set 10 | grand forks
# Processing Record 31 of Set 10 | tocopilla
# Processing Record 32 of Set 10 | barguzin
# Processing Record 33 of Set 10 | codrington
# Processing Record 34 of Set 10 | sorland
# Processing Record 35 of Set 10 | olavarria
# Processing Record 36 of Set 10 | homer
# Processing Record 37 of Set 10 | duz
# City not found. Skipping...
# Processing Record 38 of Set 10 | kushiro
# Processing Record 39 of Set 10 | mount gambier
# Processing Record 40 of Set 10 | kaliua
# Processing Record 41 of Set 10 | nelson bay
# Processing Record 42 of Set 10 | kortkeros
# Processing Record 43 of Set 10 | milkovo
# Processing Record 44 of Set 10 | monrovia
# Processing Record 45 of Set 10 | wanaka
# Processing Record 46 of Set 10 | yirol
# City not found. Skipping...
# Processing Record 47 of Set 10 | marsh harbour
# Processing Record 48 of Set 10 | fort nelson
# Processing Record 49 of Set 10 | moranbah
# Processing Record 50 of Set 10 | djenne
# Processing Record 1 of Set 11 | safaga
# Processing Record 2 of Set 11 | rovaniemi
# Processing Record 3 of Set 11 | tibiri
# Processing Record 4 of Set 11 | tawnat
# City not found. Skipping...
# Processing Record 5 of Set 11 | balakovo
# Processing Record 6 of Set 11 | kawalu
# Processing Record 7 of Set 11 | ippy
# Processing Record 8 of Set 11 | contamana
# Processing Record 9 of Set 11 | kubachi
# Processing Record 10 of Set 11 | namibe
# Processing Record 11 of Set 11 | mount pleasant
# Processing Record 12 of Set 11 | zhezkazgan
# Processing Record 13 of Set 11 | mamallapuram
# Processing Record 14 of Set 11 | horasan
# Processing Record 15 of Set 11 | balikpapan
# Processing Record 16 of Set 11 | washougal
# Processing Record 17 of Set 11 | rabo de peixe
# Processing Record 18 of Set 11 | gerash
# Processing Record 19 of Set 11 | aripuana
# Processing Record 20 of Set 11 | saint-augustin
# Processing Record 21 of Set 11 | bundibugyo
# Processing Record 22 of Set 11 | muisne
# Processing Record 23 of Set 11 | urubamba
# Processing Record 24 of Set 11 | mananjary
# Processing Record 25 of Set 11 | nemuro
# Processing Record 26 of Set 11 | vila velha
# Processing Record 27 of Set 11 | pinkafeld
# Processing Record 28 of Set 11 | beisfjord
# Processing Record 29 of Set 11 | guicheng
# City not found. Skipping...
# Processing Record 30 of Set 11 | pontianak
# Processing Record 31 of Set 11 | muchkapskiy
# Processing Record 32 of Set 11 | pringsewu
# Processing Record 33 of Set 11 | port hardy
# Processing Record 34 of Set 11 | umm kaddadah
# Processing Record 35 of Set 11 | nizhniy odes
# Processing Record 36 of Set 11 | rockland
# Processing Record 37 of Set 11 | bolkhov
# Processing Record 38 of Set 11 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 39 of Set 11 | broken hill
# Processing Record 40 of Set 11 | babushkin
# Processing Record 41 of Set 11 | maneadero
# Processing Record 42 of Set 11 | lloydminster
# Processing Record 43 of Set 11 | abha
# Processing Record 44 of Set 11 | prainha
# Processing Record 45 of Set 11 | port-gentil
# Processing Record 46 of Set 11 | el carmen
# Processing Record 47 of Set 11 | liku
# Processing Record 48 of Set 11 | waddan
# Processing Record 49 of Set 11 | kabo
# Processing Record 50 of Set 11 | klyuchi
# Processing Record 1 of Set 12 | iqaluit
# Processing Record 2 of Set 12 | kaoma
# Processing Record 3 of Set 12 | praia da vitoria
# Processing Record 4 of Set 12 | rawannawi
# City not found. Skipping...
# Processing Record 5 of Set 12 | bambanglipuro
# Processing Record 6 of Set 12 | gurlan
# Processing Record 7 of Set 12 | tarabuco
# Processing Record 8 of Set 12 | casper
# Processing Record 9 of Set 12 | doha
# Processing Record 10 of Set 12 | kargasok
# Processing Record 11 of Set 12 | henties bay
# Processing Record 12 of Set 12 | hwange
# Processing Record 13 of Set 12 | lauro muller
# Processing Record 14 of Set 12 | galle
# Processing Record 15 of Set 12 | morgantown
# Processing Record 16 of Set 12 | high level
# Processing Record 17 of Set 12 | turinskaya sloboda
# Processing Record 18 of Set 12 | pijijiapan
# Processing Record 19 of Set 12 | tuma
# Processing Record 20 of Set 12 | auki
# Processing Record 21 of Set 12 | sinkat
# City not found. Skipping...
# Processing Record 22 of Set 12 | senanga
# Processing Record 23 of Set 12 | burayevo
# Processing Record 24 of Set 12 | te anau
# Processing Record 25 of Set 12 | saint-georges
# Processing Record 26 of Set 12 | srednekolymsk
# Processing Record 27 of Set 12 | swellendam
# Processing Record 28 of Set 12 | mosquera
# Processing Record 29 of Set 12 | zolotinka
# City not found. Skipping...
# Processing Record 30 of Set 12 | mogocha
# Processing Record 31 of Set 12 | daru
# Processing Record 32 of Set 12 | ferme-neuve
# Processing Record 33 of Set 12 | boissevain
# Processing Record 34 of Set 12 | huarmey
# Processing Record 35 of Set 12 | wanlaweyn
# Processing Record 36 of Set 12 | ayan
# Processing Record 37 of Set 12 | at-bashi
# Processing Record 38 of Set 12 | ostrovnoy
# Processing Record 39 of Set 12 | kanata
# Processing Record 40 of Set 12 | rimouski
# Processing Record 41 of Set 12 | haines junction
# Processing Record 42 of Set 12 | harindanga
# Processing Record 43 of Set 12 | pacifica
# Processing Record 44 of Set 12 | lorengau
# Processing Record 45 of Set 12 | oktyabrskiy
# Processing Record 46 of Set 12 | alekseyevka
# Processing Record 47 of Set 12 | mineros
# Processing Record 48 of Set 12 | abonnema
# Processing Record 49 of Set 12 | luena
# Processing Record 50 of Set 12 | ponta do sol
# Processing Record 1 of Set 13 | kroonstad
# Processing Record 2 of Set 13 | verkh-usugli
# Processing Record 3 of Set 13 | nanortalik
# Processing Record 4 of Set 13 | nizhneyansk
# City not found. Skipping...
# Processing Record 5 of Set 13 | burica
# City not found. Skipping...
# Processing Record 6 of Set 13 | benguela
# Processing Record 7 of Set 13 | torquay
# Processing Record 8 of Set 13 | lebedinyy
# Processing Record 9 of Set 13 | riyadh
# Processing Record 10 of Set 13 | klaksvik
# Processing Record 11 of Set 13 | novyy urgal
# Processing Record 12 of Set 13 | bakhchysaray
# Processing Record 13 of Set 13 | lagos
# Processing Record 14 of Set 13 | rabaul
# Processing Record 15 of Set 13 | russell
# Processing Record 16 of Set 13 | kieta
# Processing Record 17 of Set 13 | mount isa
# Processing Record 18 of Set 13 | sumbawa
# City not found. Skipping...
# Processing Record 19 of Set 13 | ryotsu
# Processing Record 20 of Set 13 | gladstone
# Processing Record 21 of Set 13 | monticello
# Processing Record 22 of Set 13 | oksfjord
# Processing Record 23 of Set 13 | san joaquin
# Processing Record 24 of Set 13 | tura
# Processing Record 25 of Set 13 | soyo
# Processing Record 26 of Set 13 | camopi
# Processing Record 27 of Set 13 | aloleng
# Processing Record 28 of Set 13 | terrak
# Processing Record 29 of Set 13 | port blair
# Processing Record 30 of Set 13 | kasongo-lunda
# Processing Record 31 of Set 13 | pemba
# Processing Record 32 of Set 13 | basoko
# Processing Record 33 of Set 13 | krasnyy tkach
# Processing Record 34 of Set 13 | cerrito
# Processing Record 35 of Set 13 | ingham
# Processing Record 36 of Set 13 | kashan
# Processing Record 37 of Set 13 | penzance
# Processing Record 38 of Set 13 | ixtapa
# Processing Record 39 of Set 13 | padang
# Processing Record 40 of Set 13 | novobiryusinskiy
# Processing Record 41 of Set 13 | sungairaya
# Processing Record 42 of Set 13 | bull savanna
# Processing Record 43 of Set 13 | lompoc
# Processing Record 44 of Set 13 | jiazi
# Processing Record 45 of Set 13 | bestobe
# Processing Record 46 of Set 13 | ojinaga
# Processing Record 47 of Set 13 | baruun-urt
# Processing Record 48 of Set 13 | kysyl-syr
# Processing Record 49 of Set 13 | horki
# Processing Record 50 of Set 13 | javanrud
# Processing Record 1 of Set 14 | mumford
# Processing Record 2 of Set 14 | evensk
# Processing Record 3 of Set 14 | kristiinankaupunki
# Processing Record 4 of Set 14 | walla walla
# Processing Record 5 of Set 14 | celestun
# Processing Record 6 of Set 14 | ratnagiri
# Processing Record 7 of Set 14 | lensk
# Processing Record 8 of Set 14 | jalu
# Processing Record 9 of Set 14 | maumere
# Processing Record 10 of Set 14 | puerto escondido
# Processing Record 11 of Set 14 | muheza
# Processing Record 12 of Set 14 | khanpur
# Processing Record 13 of Set 14 | ugoofaaru
# Processing Record 14 of Set 14 | teya
# Processing Record 15 of Set 14 | half moon bay
# Processing Record 16 of Set 14 | ampanihy
# Processing Record 17 of Set 14 | khios
# City not found. Skipping...
# Processing Record 18 of Set 14 | calama
# Processing Record 19 of Set 14 | carbonia
# Processing Record 20 of Set 14 | monywa
# Processing Record 21 of Set 14 | baykit
# Processing Record 22 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 23 of Set 14 | xiaoshi
# Processing Record 24 of Set 14 | katsuura
# Processing Record 25 of Set 14 | katangli
# Processing Record 26 of Set 14 | rosarito
# Processing Record 27 of Set 14 | karratha
# Processing Record 28 of Set 14 | hirara
# Processing Record 29 of Set 14 | jawhar
# Processing Record 30 of Set 14 | pangai
# Processing Record 31 of Set 14 | sembakung
# Processing Record 32 of Set 14 | murgab
# Processing Record 33 of Set 14 | pasir gudang
# Processing Record 34 of Set 14 | kiama
# Processing Record 35 of Set 14 | soto
# Processing Record 36 of Set 14 | leh
# Processing Record 37 of Set 14 | buckingham
# Processing Record 38 of Set 14 | jiaozuo
# Processing Record 39 of Set 14 | qom
# Processing Record 40 of Set 14 | chibombo
# Processing Record 41 of Set 14 | gimli
# Processing Record 42 of Set 14 | the pas
# Processing Record 43 of Set 14 | dogondoutchi
# Processing Record 44 of Set 14 | linqiong
# Processing Record 45 of Set 14 | ullapool
# Processing Record 46 of Set 14 | nicoya
# Processing Record 47 of Set 14 | winneba
# Processing Record 48 of Set 14 | baherden
# Processing Record 49 of Set 14 | payyannur
# Processing Record 50 of Set 14 | darhan
# Processing Record 1 of Set 15 | kemin
# Processing Record 2 of Set 15 | idritsa
# Processing Record 3 of Set 15 | saeby
# Processing Record 4 of Set 15 | marienburg
# Processing Record 5 of Set 15 | cross lanes
# Processing Record 6 of Set 15 | wanning
# Processing Record 7 of Set 15 | tasbuget
# City not found. Skipping...
# Processing Record 8 of Set 15 | valparaiso
# Processing Record 9 of Set 15 | pacific grove
# Processing Record 10 of Set 15 | fomboni
# Processing Record 11 of Set 15 | ayotzintepec
# Processing Record 12 of Set 15 | hofn
# Processing Record 13 of Set 15 | oeiras do para
# Processing Record 14 of Set 15 | jaciara
# Processing Record 15 of Set 15 | armacao dos buzios
# City not found. Skipping...
# Processing Record 16 of Set 15 | atar
# Processing Record 17 of Set 15 | yaguajay
# Processing Record 18 of Set 15 | ouahigouya
# Processing Record 19 of Set 15 | hearst
# Processing Record 20 of Set 15 | chara
# Processing Record 21 of Set 15 | zabol
# Processing Record 22 of Set 15 | wajir
# Processing Record 23 of Set 15 | cucutilla
# Processing Record 24 of Set 15 | okhotsk
# Processing Record 25 of Set 15 | bratsk
# Processing Record 26 of Set 15 | palaikastron
# Processing Record 27 of Set 15 | shagonar
# Processing Record 28 of Set 15 | agadez
# Processing Record 29 of Set 15 | morant bay
# Processing Record 30 of Set 15 | saint-joseph
# Processing Record 31 of Set 15 | mataram
# Processing Record 32 of Set 15 | cockburn town
# Processing Record 33 of Set 15 | vreed en hoop
# City not found. Skipping...
# Processing Record 34 of Set 15 | sarakhs
# Processing Record 35 of Set 15 | luanda
# Processing Record 36 of Set 15 | tongliao
# Processing Record 37 of Set 15 | chapais
# Processing Record 38 of Set 15 | seinajoki
# Processing Record 39 of Set 15 | sorrento
# Processing Record 40 of Set 15 | pemangkat
# Processing Record 41 of Set 15 | paamiut
# Processing Record 42 of Set 15 | vaitape
# Processing Record 43 of Set 15 | toungoo
# City not found. Skipping...
# Processing Record 44 of Set 15 | lagunas
# Processing Record 45 of Set 15 | sakaiminato
# Processing Record 46 of Set 15 | port-cartier
# Processing Record 47 of Set 15 | mingaora
# Processing Record 48 of Set 15 | totma
# Processing Record 49 of Set 15 | contai
# Processing Record 50 of Set 15 | marawi
# Processing Record 1 of Set 16 | cassilandia
# Processing Record 2 of Set 16 | nizhnevartovsk
# Processing Record 3 of Set 16 | ijaki
# City not found. Skipping...
# Processing Record 4 of Set 16 | santa rosa
# Processing Record 5 of Set 16 | khani
# Processing Record 6 of Set 16 | tabora
# Processing Record 7 of Set 16 | chapleau
# Processing Record 8 of Set 16 | el ocotito
# Processing Record 9 of Set 16 | nidzica
# Processing Record 10 of Set 16 | kungurtug
# Processing Record 11 of Set 16 | kloulklubed
# Processing Record 12 of Set 16 | soe
# Processing Record 13 of Set 16 | florianopolis
# Processing Record 14 of Set 16 | maceio
# Processing Record 15 of Set 16 | krasnyy oktyabr
# Processing Record 16 of Set 16 | hervey bay
# Processing Record 17 of Set 16 | pangnirtung
# Processing Record 18 of Set 16 | gamba
# Processing Record 19 of Set 16 | coruripe
# Processing Record 20 of Set 16 | omutninsk
# Processing Record 21 of Set 16 | den helder
# Processing Record 22 of Set 16 | salitral
# Processing Record 23 of Set 16 | channel-port aux basques
# Processing Record 24 of Set 16 | igunga
# Processing Record 25 of Set 16 | halalo
# City not found. Skipping...
# Processing Record 26 of Set 16 | margate
# Processing Record 27 of Set 16 | phalaborwa
# Processing Record 28 of Set 16 | ruatoria
# City not found. Skipping...
# Processing Record 29 of Set 16 | krasnoselkup
# Processing Record 30 of Set 16 | kudahuvadhoo
# Processing Record 31 of Set 16 | xining
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 716

# %%
# Convert the array of dictionaries to a Pandas dataframe
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       Kapaa  22.0752 -159.3190     84.18        76          75        5.01
# 1     Qaanaaq  77.4840  -69.3632     -5.22        60           0       10.27
# 2    Sheridan  44.8333 -106.9173     55.78        46           1        1.01
# 3      Atuona  -9.8000 -139.0333     78.19        73           8       18.99
# 4       Vaini -21.2000 -175.2000     78.96        78          20       13.80
# 5      Dikson  73.5069   80.5464     10.76        88         100       17.83
# 6       Ancud -41.8697  -73.8203     54.43        85         100       18.66
# 7  Rio Grande -32.0350  -52.0986     52.95        70           0        8.23
# 8       Rocha -34.4833  -54.3333     60.73        57           0       13.33
# 9     Hualmay -11.0964  -77.6139     63.32        80          46       10.31
#
#   Country Weather Description                 Date
# 0      US       broken clouds  2021-10-25 00:48:56
# 1      GL           clear sky  2021-10-25 00:47:21
# 2      US           clear sky  2021-10-25 00:49:48
# 3      PF           clear sky  2021-10-25 00:46:32
# 4      TO          few clouds  2021-10-25 00:49:49
# 5      RU     overcast clouds  2021-10-25 00:49:49
# 6      CL     overcast clouds  2021-10-25 00:46:39
# 7      BR           clear sky  2021-10-25 00:49:50
# 8      UY           clear sky  2021-10-25 00:49:50
# 9      PE    scattered clouds  2021-10-25 00:49:50

# %%
# Reorder columns alphabetically
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Weather Description", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#          City Country                 Date      Lat       Lng  \
# 0       Kapaa      US  2021-10-25 00:48:56  22.0752 -159.3190
# 1     Qaanaaq      GL  2021-10-25 00:47:21  77.4840  -69.3632
# 2    Sheridan      US  2021-10-25 00:49:48  44.8333 -106.9173
# 3      Atuona      PF  2021-10-25 00:46:32  -9.8000 -139.0333
# 4       Vaini      TO  2021-10-25 00:49:49 -21.2000 -175.2000
# 5      Dikson      RU  2021-10-25 00:49:49  73.5069   80.5464
# 6       Ancud      CL  2021-10-25 00:46:39 -41.8697  -73.8203
# 7  Rio Grande      BR  2021-10-25 00:49:50 -32.0350  -52.0986
# 8       Rocha      UY  2021-10-25 00:49:50 -34.4833  -54.3333
# 9     Hualmay      PE  2021-10-25 00:49:50 -11.0964  -77.6139
#
#   Weather Description  Max Temp  Humidity  Cloudiness  Wind Speed
# 0       broken clouds     84.18        76          75        5.01
# 1           clear sky     -5.22        60           0       10.27
# 2           clear sky     55.78        46           1        1.01
# 3           clear sky     78.19        73           8       18.99
# 4          few clouds     78.96        78          20       13.80
# 5     overcast clouds     10.76        88         100       17.83
# 6     overcast clouds     54.43        85         100       18.66
# 7           clear sky     52.95        70           0        8.23
# 8           clear sky     60.73        57           0       13.33
# 9    scattered clouds     63.32        80          46       10.31

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
